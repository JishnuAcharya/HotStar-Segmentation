# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
from pandas.io.json import json_normalize
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data=pd.read_csv('/content/gdrive/My Drive/hotstar_train.csv')
data=data.drop('Unnamed: 0',axis=1)

# %%
data.head()
# Out:
#        Train_ID  ...                                                tod
# 0  train-121672  ...                             18:1372,21:1862,17:320
# 1  train-121673  ...  11:7726,10:3521,13:2067,12:3844,20:4608,21:936...
# 2  train-121670  ...  11:302,10:1594,13:331,12:133,20:3802,14:3083,2...
# 3  train-121671  ...                  10:122,12:77,15:1800,14:0,16:2083
# 4  train-121676  ...         20:529,21:1257,22:4930,23:538,19:1268,18:6
#
# [5 rows x 7 columns]

# %% [markdown]
# ## 1.Treating for cities and time

# %%
df_cities_seg=data[['Train_ID','cities','segment']]

# %%
x=df_cities_seg

# %%
city=[i for i in x.cities]
cities=[]
time=[]
for i in range(0,len(city)):
    t=city[i].split(',')
    for j in range(len(t)):
        t1=t[j].split(':')
        cities.append(t1[0])
        time.append(t1[1])
time=[int(x) for x in time]
#time

# %%
cities_unique=list(set(cities))
len(cities_unique)
# Out:
# 1358

# %% [markdown]
# #### Function for cleaning

# %%
def add_columns(x,col):
    for i in range(0,len(col)):
        x[col[i]]=np.NaN
def add_columns_time(x,col):
    for i in range(0,len(col)):
        x['time_',col[i]]=np.NaN
        
# add value to column
def value_columns(x):
    tt=[]
    tc=[]
    for i in range(0,len(x)):
        t=x.iloc[i,1].split(',')
        for j in range(0,len(t)):
            t1=t[j].split(':')
            #t1.append(t1)
            tc.append(t1[0])
            tt.append(t1[1])
        for j in range(0,len(tc)):
            x[tc[j]][i]=1
        
        tc=[]
def value_time(x,col):
    city=[]
    time=[]
    for i in range(0,len(x1)):
        temp=x[col][i].split(',')
    #    for j in range(0,len(temp)):
    #        x2=temp[j]
    #        city.append(x2.split(':')[0])
    #        time.append(x2.split(':')[1])
        for j in range(0,len(temp)):
            if x[temp[j].split(':')[0]][i]==1:
                x['time_',temp[j].split(':')[0]][i]=temp[j].split(':')[1]
                
def fill_nulls_time(x):
    for i in range(0,len(x)):
        for j in range(3,len(x.columns)):
    #        print('t')
            if x.iloc[i,j]>=0:
                #print('t')
                x.iloc[i,j]=x.iloc[i,j]
            else :
                x.iloc[i,j]=0   
    
def fill_nulls_city(x,cols):
    for i in range(0,len(x)):
        for j in range(0,len(cols)):
    #        print('t')
            if x[cols[j]][i]!=1:
                #print('t')
                x[cols[j]][i]=0
def int_to_float(x):
    for i in range(0,len(x.columns)):
        if x.iloc[:,i].dtypes=='float64':
            x.iloc[:,i]=x.iloc[:,i].astype('int')

# %%
# Add column to dataframe
add_columns(x,cities_unique)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x.head()
# Out:
#        Train_ID                                         cities  ... boston  athina
# 0  train-121672                           delhi:3492,mumbai:64  ...    NaN     NaN
# 1  train-121673                   ahmedabad:56666,mumbai:26989  ...    NaN     NaN
# 2  train-121670                              navi mumbai:29400  ...    NaN     NaN
# 3  train-121671           chennai:77,navi mumbai:4005,mumbai:0  ...    NaN     NaN
# 4  train-121676  bangalore:5135,krishnarajapura:529,hosur:2864  ...    NaN     NaN
#
# [5 rows x 1361 columns]

# %%
x.shape
# Out:
# (200000, 1361)

# %%
### Add value to column where it was present

# %%
value_columns(x)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x
# Out:
#             Train_ID  ... City_Total_Time
# 0       train-121672  ...               0
# 1       train-121673  ...               0
# 2       train-121670  ...               0
# 3       train-121671  ...               0
# 4       train-121676  ...               0
# ...              ...  ...             ...
# 199995  train-126324  ...               0
# 199996  train-126327  ...               0
# 199997  train-126326  ...               0
# 199998  train-126329  ...               0
# 199999  train-126328  ...               0
#
# [200000 rows x 1362 columns]

# %%
#### Replacing the null with 0
fill_nulls_city(x,cities_unique)

# %%
# changing float to int
for i in range(0,len(x.columns)):
    if x.iloc[:,i].dtypes=='float64':
        x.iloc[:,i]=x.iloc[:,i].astype('int')

# %%
x.head()
# Out:
#        Train_ID  ... mysore
# 0  train-121672  ...    NaN
# 1  train-121673  ...    NaN
# 2  train-121670  ...    NaN
# 3  train-121671  ...    NaN
# 4  train-121676  ...    NaN
#
# [5 rows x 1361 columns]

# %%
len(cities)
# Out:
# 382505

# %%
# add time with respect to cities
add_columns_time(x,cities_unique)

# %%
# fill times value
#value_time(x,cities,time)

# %%
x.head()

# %%
# fill null values in time
#fill_nulls_time(x)

# %%
x.head()
# Out:
#        Train_ID  ... City_Total_Time
# 0  train-121672  ...               0
# 1  train-121673  ...               0
# 2  train-121670  ...               0
# 3  train-121671  ...               0
# 4  train-121676  ...               0
#
# [5 rows x 1362 columns]

# %%
city=[]
time=[]
x['City_Total_Time']=0
for i in range(0,len(x)):
  #print(i)
  temp=x['cities'][i].split(',')
  li=[]
  #print(int(temp[0].split(':')[1])+8)
  for j in range(0,len(temp)):
    if x[temp[j].split(':')[0]][i]==1.0:
      print('Hell')
        #print(int(x[temp[j].split(':')[1]]))
        #num=x[temp[j].split(':')[1]]
        #li.append('1')
      num=(int(x[temp[j].split(':')[1]]))
  #x['City_Total_Time'][i]=sum(li)
# Out:
# Hell
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3492'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-1274423c7b72> in <module>()
#      13         #num=x[temp[j].split(':')[1]]
#      14         #li.append('1')
# ---> 15       print(int(x[temp[j].split(':')[1]]))
#      16   #x['City_Total_Time'][i]=sum(li)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3492'

# %%
x.head()
# Out:
#        Train_ID  ... (time_, mysore)
# 0  train-121672  ...             NaN
# 1  train-121673  ...             NaN
# 2  train-121670  ...             NaN
# 3  train-121671  ...             NaN
# 4  train-121676  ...             NaN
#
# [5 rows x 2719 columns]

# %%
# filling nulls in time
fill_nulls_time(x)

# %%
x.head()
# Out:
#        Train_ID  ... (time_, odesa)
# 0  train-121672  ...            NaN
# 1  train-121673  ...            NaN
# 2  train-121670  ...            NaN
# 3  train-121671  ...            NaN
# 4  train-121676  ...            NaN
#
# [5 rows x 2719 columns]

# %%
# changing float to int
for i in range(0,len(x.columns)):
    if x.iloc[:,i].dtypes=='float64':
        x.iloc[:,i]=x.iloc[:,i].astype('int')

# %%
x.head()
# Out:
#        Train_ID  ... (time_, odesa)
# 0  train-121672  ...            NaN
# 1  train-121673  ...            NaN
# 2  train-121670  ...            NaN
# 3  train-121671  ...            NaN
# 4  train-121676  ...            NaN
#
# [5 rows x 2719 columns]

# %%
x.tail()
# Out:
#             Train_ID  ... (time_, odesa)
# 199995  train-126324  ...            NaN
# 199996  train-126327  ...            NaN
# 199997  train-126326  ...            NaN
# 199998  train-126329  ...            NaN
# 199999  train-126328  ...            NaN
#
# [5 rows x 2719 columns]

# %%
# storing dataframe in df_cities
df_cities=x.copy()
df_cities.to_csv('hotstar_cities_200000.csv')

# %%
from google.colab import files
files.download('hotstar_cities_200000.csv')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 56100, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 320, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 351, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 364, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 724, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 803, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------

# %% [markdown]
# ## 2.Treating for day of the week and time

# %%
data.columns

# %%
x=data[['Train_ID','dow','segment']]

# %%
## spliting day and time
day=[]
time=[]
for i in range(0,len(x)):
    temp=x['dow'][i]
    temp=temp.split(',')
    for j in range(0,len(temp)):
        day.append(temp[j].split(':')[0])
        time.append(temp[j].split(':')[1])

# %%
x.dow.head()
# Out:
# 0                                    5:482,4:3008,7:64
# 1    1:3257,3:9162,2:12893,5:9237,4:8503,7:25094,6:...
# 2       1:40,3:2700,2:4659,5:7338,4:6641,7:2218,6:5800
# 3                                    1:77,2:3883,5:122
# 4                                        1:6150,3:2378
# Name: dow, dtype: object

# %% [markdown]
# #### function to treat days and time

# %%
def day_name(l):
    #day_name=['Sun','Mon','Tue','Wed','Thu','Fri','Sat']
    for i in range(0,len(l)):
        if l[i]=='1':
            l[i]='Sun'
        elif l[i]=='2':
            l[i]='Mon'
        elif l[i]=='3':
            l[i]='Tue'
        elif l[i]=='4':
            l[i]='Wed'
        elif l[i]=='5':
            l[i]='Thu'
        elif l[i]=='6':
            l[i]='Fri'
        else:
            l[i]='Sat'

# %%
#changing days to day name
day_name(day)

# %%
day_unique=list(set(day))

# %%
add_columns(x,day_unique)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
day[:10]
# Out:
# ['Thu', 'Wed', 'Sat', 'Sun', 'Tue', 'Mon', 'Thu', 'Wed', 'Sat', 'Fri']

# %%
x.head(10)
# Out:
#        Train_ID                                                dow  ... Fri  Sun
# 0  train-121672                                  5:482,4:3008,7:64  ... NaN  NaN
# 1  train-121673  1:3257,3:9162,2:12893,5:9237,4:8503,7:25094,6:...  ... NaN  NaN
# 2  train-121670     1:40,3:2700,2:4659,5:7338,4:6641,7:2218,6:5800  ... NaN  NaN
# 3  train-121671                                  1:77,2:3883,5:122  ... NaN  NaN
# 4  train-121676                                      1:6150,3:2378  ... NaN  NaN
# 5  train-121677                                                2:5  ... NaN  NaN
# 6  train-121674          1:15909,3:2465,2:5580,4:293,7:1283,6:4131  ... NaN  NaN
# 7  train-121675                            3:5481,4:724,7:373,6:77  ... NaN  NaN
# 8  train-121678     1:6965,3:21,2:6183,5:1434,4:6995,7:4599,6:3923  ... NaN  NaN
# 9  train-121679                                        1:1043,7:37  ... NaN  NaN
#
# [10 rows x 10 columns]

# %%
# filling values to the columns
for i in range(0,len(x)):
    day_t=[]
    s=x.dow[i]
    s=s.split(',')
    for j in range(0,len(s)):
        d=s[j].split(':')[0]
        t=s[j].split(':')[1]
        if d=='1':
            d='Sun'
        elif d=='2':
            d='Mon'
        elif d=='3':
            d='Tue'
        elif d=='4':
            d='Wed'
        elif d=='5':
            d='Thu'
        elif d=='6':
            d='Fri'
        else:
            d='Sat'
        day_t.append(d)
        for k in range(0,len(day_t)):
            x[day_t[k]][i]=1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# filling the nulls with 0
fill_nulls_city(x,day_unique)

# %%
x.head(10)
# Out:
#        Train_ID                                                dow  ...  Fri  Sun
# 0  train-121672                                  5:482,4:3008,7:64  ...  NaN  NaN
# 1  train-121673  1:3257,3:9162,2:12893,5:9237,4:8503,7:25094,6:...  ...  1.0  1.0
# 2  train-121670     1:40,3:2700,2:4659,5:7338,4:6641,7:2218,6:5800  ...  1.0  1.0
# 3  train-121671                                  1:77,2:3883,5:122  ...  NaN  1.0
# 4  train-121676                                      1:6150,3:2378  ...  NaN  1.0
# 5  train-121677                                                2:5  ...  NaN  NaN
# 6  train-121674          1:15909,3:2465,2:5580,4:293,7:1283,6:4131  ...  1.0  1.0
# 7  train-121675                            3:5481,4:724,7:373,6:77  ...  1.0  NaN
# 8  train-121678     1:6965,3:21,2:6183,5:1434,4:6995,7:4599,6:3923  ...  1.0  1.0
# 9  train-121679                                        1:1043,7:37  ...  NaN  1.0
#
# [10 rows x 10 columns]

# %%
# changing data type from float to int
int_to_float(x)

# %%
x.head(10)

# %%
## adding columns for time
add_columns_time(x,day_unique)

# %%
x.head()
# Out:
#        Train_ID  ... (time_, Sun)
# 0  train-121672  ...          NaN
# 1  train-121673  ...          NaN
# 2  train-121670  ...          NaN
# 3  train-121671  ...          NaN
# 4  train-121676  ...          NaN
#
# [5 rows x 17 columns]

# %%
## fill the value of time

for i in range(0,len(x1)):
    temp=x['dow'][i].split(',')
    for j in range(0,len(temp)):
        d=temp[j].split(':')[0]
        if d=='1':
            d='Sun'
        elif d=='2':
            d='Mon'
        elif d=='3':
            d='Tue'
        elif d=='4':
            d='Wed'
        elif d=='5':
            d='Thu'
        elif d=='6':
            d='Fri'
        else:
            d='Sat'
        if x[d][i]==1:
            x['time_',d][i]=int(temp[j].split(':')[1])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x.head()

# %%
## fill the values of nulls with 0
fill_nulls_time(x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-3fe21a428928> in <module>()
# ----> 1 fill_nulls_time(x)
#
# <ipython-input-8-1ab75036d767> in fill_nulls_time(x)
#      42                 x.iloc[i,j]=x.iloc[i,j]
#      43             else :
# ---> 44                 x.iloc[i,j]=0
#      45
#      46 def fill_nulls_city(x,cols):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     555                 # scalar
#     556                 for item in labels:
# --> 557                     setter(item, value)
#     558
#     559         else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in setter(item, v)
#     492
#     493                 # reset the sliced object if unique
# --> 494                 self.obj[item] = s
#     495
#     496             # we need an iterable, with a ndim of at least 1
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3485         else:
#    3486             # set column
# -> 3487             self._set_item(key, value)
#    3488
#    3489     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3563         self._ensure_valid_index(value)
#    3564         value = self._sanitize_column(key, value)
# -> 3565         NDFrame._set_item(self, key, value)
#    3566
#    3567         # check if we are modifying a copy
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3379
#    3380     def _set_item(self, key, value):
# -> 3381         self._data.set(key, value)
#    3382         self._clear_item_cache()
#    3383
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1067
#    1068         try:
# -> 1069             loc = self.items.get_loc(item)
#    1070         except KeyError:
#    1071             # This item wasn't present, just insert at end
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# KeyboardInterrupt:

# %%
x.head()
# Out:
#        Train_ID  ... (time_, Sun)
# 0  train-121672  ...          NaN
# 1  train-121673  ...       3257.0
# 2  train-121670  ...         40.0
# 3  train-121671  ...         77.0
# 4  train-121676  ...       6150.0
#
# [5 rows x 17 columns]

# %%
## changing float to int
int_to_float(x)

# %%
x.head()

# %%
df_days=x.copy()
df_days.to_csv('hotstar_days_200000.csv')

# %%
files.download('hotstar_days_200000.csv')

# %% [markdown]
# ## 3.Treating the values for genres

# %%
x=data[['Train_ID','genres','segment']]

# %%
x.head()
# Out:
#        Train_ID                                             genres segment
# 0  train-121672                   Drama:6,Cricket:3469,Wildlife:79     neg
# 1  train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...     neg
# 2  train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...     neg
# 3  train-121671                  Romance:77,Drama:122,Cricket:3883     neg
# 4  train-121676                                      TalkShow:8529     pos

# %%
genre=[]
time=[]
for i in range(0,len(x)):
    gen=x['genres'][i].split(',')
    for j in range(0,len(gen)):
        genre.append(gen[j].split(':')[0])
        time.append(gen[j].split(':')[1])

# %%
time=[int(x) for x in time]

# %%
genre_unique=list(set(genre))

# %%
# adding columns for genre
add_columns(x,genre_unique)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x.head()
# Out:
#        Train_ID  ... Table Tennis
# 0  train-121672  ...          NaN
# 1  train-121673  ...          NaN
# 2  train-121670  ...          NaN
# 3  train-121671  ...          NaN
# 4  train-121676  ...          NaN
#
# [5 rows x 38 columns]

# %%
# adding value for genre
value_columns(x)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x.head()
# Out:
#        Train_ID  ... Table Tennis
# 0  train-121672  ...          NaN
# 1  train-121673  ...          NaN
# 2  train-121670  ...          NaN
# 3  train-121671  ...          NaN
# 4  train-121676  ...          NaN
#
# [5 rows x 38 columns]

# %%
# filling nulls in genre
fill_nulls_city(x,genre_unique)

# %%
x.head()

# %%
# changing floats to int
int_to_float(x)

# %%
# adding columns for time
add_columns_time(x,genre_unique)

# %%
x.head()
# Out:
#        Train_ID  ... (time_, Table Tennis)
# 0  train-121672  ...                   NaN
# 1  train-121673  ...                   NaN
# 2  train-121670  ...                   NaN
# 3  train-121671  ...                   NaN
# 4  train-121676  ...                   NaN
#
# [5 rows x 73 columns]

# %%
# adding values for time
for i in range(0,len(x)):
    temp=x['genres'][i].split(',')
    #    for j in range(0,len(temp)):
    #        x2=temp[j]
    #        city.append(x2.split(':')[0])
    #        time.append(x2.split(':')[1])
    for j in range(0,len(temp)):
        if x[temp[j].split(':')[0]][i]==1:
            x['time_',temp[j].split(':')[0]][i]=temp[j].split(':')[1]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
x.head()
# Out:
#        Train_ID  ... (time_, Table Tennis)
# 0  train-121672  ...                   NaN
# 1  train-121673  ...                   NaN
# 2  train-121670  ...                   NaN
# 3  train-121671  ...                   NaN
# 4  train-121676  ...                   NaN
#
# [5 rows x 73 columns]

# %%
# fill nulls for time
fill_nulls_time(x)

# %%
x.head()

# %%
# converting float to int
int_to_float(x)

# %%
x.head()

# %%
x.columns=[            'Train_ID',               'genres',              'segment',
                     'Comedy',               'Action',            'Badminton',
                    'Reality',             'Wildlife',                 'Kids',
                      'Sport',              'Romance',             'Formula1',
                   'Thriller',                'Drama',                 'Teen',
                   'Football',               'Awards',              'Cricket',
                      'Crime',               'LiveTV',               'Travel',
                   'TalkShow',            'Mythology',               'Family',
                    'Science','time_Comedy',    'time_Action',
'time_Badminton',   'time_Reality',  'time_Wildlife',
            'time_Kids',     'time_Sport',   'time_Romance',
        'time_Formula1',  'time_Thriller',     'time_Drama',
            'time_Teen',  'time_Football',    'time_Awards',
         'time_Cricket',     'time_Crime',    'time_LiveTV',
          'time_Travel',  'time_TalkShow', 'time_Mythology',
          'time_Family',   'time_Science']

# %%
df_genre=x.copy()

# %%
df_genre.to_csv('Hotstar_genre_20000.csv')

# %%
files.download('Hotstar_genre_20000.csv')
